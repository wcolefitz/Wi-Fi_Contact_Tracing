# %%
import import_ipynb #if this doesn't work, run 'pip install import-ipynb'

import numpy as np


from Algorithms_Functions import *
from Join_Functions import *
from import_script_master import *
from algorithm_analysis import *

import matplotlib.pyplot as plt


import simpleaudio as sa
import os
abs_path=os.path.expanduser("~/Google Drive/WashU/WashU Fall 2020/Capstone Project/Capstone Project_Shared Folder/Data/Plots/Normalized_Min/")
# Out:
# importing Jupyter notebook from algorithm_analysis.ipynb

# %%
dist_dic={(49,54):[0,2,4,6,8,10],(55,61):[0,2,4,6,8,10,12],(62,68):[0,2,4,6,8,10,12]} #dont change me
#dist_dic={(39,42):[0,4,9,15]}

# %%
wave_obj = sa.WaveObject.from_wave_file("tone.wav")

for i in dist_dic.keys():
    Analyze_and_Plot(['CF','CB'], i[0], i[1], 60, euc_distance, dist_dic[i], '', True, 'Euclidean Distance','CF','Euclidean Distance')
play_obj = wave_obj.play()    
play_obj.wait_done()
# Out:
# y-intercept
# 46.094006336262666
# slope
# 0.658837969870298
#                                    algorithm     slope      y_int  \
# 0  <function euc_distance at 0x7f9e6139d790>  0.658838  46.094006
#
#    Avg_%_Error        r2  ss_res_over_n  ss_res_over_nm  res_over_tot_over_m
# 0     0.125382  0.041403       55.80494        84.70207             1.454981
# y-intercept
# 16.774379986809244
# slope
# 0.8273936424901602
#                                    algorithm     slope     y_int  Avg_%_Error  \
# 0  <function euc_distance at 0x7f9e6139d790>  0.827394  16.77438     0.137989
#
#          r2  ss_res_over_n  ss_res_over_nm  res_over_tot_over_m
# 0  0.227904      11.361348       13.731491             0.933167
# y-intercept
# 29.89900676971003
# slope
# 0.04131596119479445
#                                    algorithm     slope      y_int  \
# 0  <function euc_distance at 0x7f9e6139d790>  0.041316  29.899007
#
#    Avg_%_Error        r2  ss_res_over_n  ss_res_over_nm  res_over_tot_over_m
# 0     0.129292  0.002523      16.961839      410.539625            24.142643
